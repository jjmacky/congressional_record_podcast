# %%
import os
from bs4 import BeautifulSoup
import re

def extract_titles_from_htm(directory_path):
    titles = {}

    for filename in os.listdir(directory_path):
        if filename.endswith('.htm'):
            file_path = os.path.join(directory_path, filename)

            with open(file_path, 'r', encoding='utf-8') as file:
                soup = BeautifulSoup(file, 'html.parser')
                body_text = soup.get_text()

                # Find the position of the GPO link
                gpo_link_index = body_text.find('www.gpo.gov')

                if gpo_link_index != -1:
                    # Extract the text after GPO link
                    text_after_gpo_link = body_text[gpo_link_index + len('www.gpo.gov'):]

                    # Find the first all-uppercase line after the GPO link
                    for line in text_after_gpo_link.splitlines():
                        if line.isupper():
                            titles[filename] = line.strip()
                            break
                    else:
                        titles[filename] = 'No Title Found'
                else:
                    titles[filename] = 'GPO Link Not Found'

    return titles

def print_titles_in_columns(titles):
    print(f"{'Filename':<50} | {'Title'}")
    print('-' * 100)  # Print a separator line

    for filename, title in titles.items():
        print(f"{filename:<50} | {title}")


# Usage example
directory_path = '../Episodes/CREC-2023-05-22/html'
titles = extract_titles_from_htm(directory_path)
print_titles_in_columns(titles)
# Out:
# Filename                                           | Title
# ----------------------------------------------------------------------------------------------------
# CREC-2023-05-22-pt1-PgE472-3.htm                   | CELEBRATING THE 98TH BIRTHDAY OF TRINI GOMEZ
# CREC-2023-05-22-pt1-PgH2479.htm                    | VETERANS' COMPENSATION COST-OF-LIVING ADJUSTMENT ACT OF 2023
# CREC-2023-05-22-pt1-PgH2486.htm                    | COMMEMORATING THE LIFE AND LEGACY OF DR. NICHOLAS BALABKINS
# CREC-2023-05-22-pt1-PgH2502-9.htm                  | H.R. 3585.
# CREC-2023-05-22-pt1-PgE474-5.htm                   | RECOGNIZING CLINT JOHNSTON
# CREC-2023-05-22-pt1-PgE474-4.htm                   | PERSONAL EXPLANATION
# CREC-2023-05-22-pt1-PgH2502-8.htm                  | H.R. 3584.
# CREC-2023-05-22-pt1-PgE472-2.htm                   | RECOGNIZING CHIEF GARY SPARKS' 40 YEARS OF SERVICE AS A FIREFIGHTER FOR
# CREC-2023-05-22-pt1-PgH2502-20.htm                 | ADDITIONAL SPONSORS
# CREC-2023-05-22-pt1-PgH2469-5.htm                  | PREVENTING THE FINANCING OF ILLEGAL SYNTHETIC DRUGS ACT
# CREC-2023-05-22-pt1-PgH2485.htm                    | PRAISING THE LIFE AND CAREER OF RENEE POWELL
# CREC-2023-05-22-pt1-PgE476-4.htm                   | HONORING JAIME CARRANZA
# CREC-2023-05-22-pt1-PgH2491.htm                    | 2023 SPECIES WEEK
# CREC-2023-05-22-pt1-PgH2484.htm                    | THE JOURNAL
# CREC-2023-05-22-pt1-PgH2469-4.htm                  | ANNOUNCEMENT BY THE SPEAKER PRO TEMPORE
# CREC-2023-05-22-pt1-PgE472-5.htm                   | INTRODUCTION OF THE DISTRICT OF COLUMBIA TRANSPORTATION FUNDING
# CREC-2023-05-22-pt1-PgE474-3.htm                   | HONORING UNITED STATES NAVY AIRBORNE EARLY WARNING SQUADRON ONE
# CREC-2023-05-22-pt1-PgD489.htm                     | CONGRESSIONAL RECORD (USPS 087-390).
# CREC-2023-05-22-pt1-PgD488.htm                     | COMMITTEE MEETINGS FOR TUESDAY,
# CREC-2023-05-22-pt1-PgE474-2.htm                   | HON. JERRY L. CARL
# CREC-2023-05-22-pt1-PgH2481.htm                    | NOTAM IMPROVEMENT ACT OF 2023
# CREC-2023-05-22-pt1-PgE472-4.htm                   | HONORING THE 55TH ANNIVERSARY OF THE USS SCORPION'S DISAPPEARANCE
# CREC-2023-05-22-pt1-PgH2502-18.htm                 | H.R. 3594.
# CREC-2023-05-22-pt1-PgH2469-3.htm                  | AFTER RECESS
# CREC-2023-05-22-pt1-PgH2468.htm                    | PAYING TRIBUTE ON MEMORIAL DAY
# CREC-2023-05-22-pt1-PgH2497.htm                    | ADJOURNMENT
# CREC-2023-05-22-pt1-PgH2483.htm                    | ANNOUNCEMENT BY THE SPEAKER PRO TEMPORE
# CREC-2023-05-22-pt1-PgE476-2.htm                   | HONORING FRANCIS XAVIER BELLOTTI OF BOSTON, MASSACHUSETTS, IN
# CREC-2023-05-22-pt1-PgE476-3.htm                   | PERSONAL EXPLANATION
# CREC-2023-05-22-pt1-PgH2482.htm                    | RECESS
# CREC-2023-05-22-pt1-PgH2469.htm                    | COMMUNICATION FROM THE DEMOCRATIC LEADER
# CREC-2023-05-22-pt1-PgH2469-2.htm                  | RECESS
# CREC-2023-05-22-pt1-PgH2502-19.htm                 | H.R. 3595.
# CREC-2023-05-22-pt1-PgH2501-8.htm                  | H.R. 3561.
# CREC-2023-05-22-pt1-PgH2501-13.htm                 | H.R. 3566.
# CREC-2023-05-22-pt1-PgH2468-5.htm                  | APPOINTMENT OF MEMBER TO BOARD OF VISITORS TO THE UNITED STATES COAST
# CREC-2023-05-22-pt1-PgE471-2.htm                   | HONORING MICHAEL SHORT
# CREC-2023-05-22-pt1-PgE471-3.htm                   | PERSONAL EXPLANATION
# CREC-2023-05-22-pt1-PgH2468-4.htm                  | COMMUNICATION FROM THE CLERK OF THE HOUSE
# CREC-2023-05-22-pt1-PgH2501-12.htm                 | H.R. 3565.
# CREC-2023-05-22-pt1-PgH2501-9.htm                  | H.R. 3562.
# CREC-2023-05-22-pt1-PgH2501-10.htm                 | H.R. 3563.
# CREC-2023-05-22-pt1-PgH2468-6.htm                  | APPOINTMENT OF MEMBER TO BOARD OF VISITORS TO THE UNITED STATES AIR
# CREC-2023-05-22-pt1-PgE473-3.htm                   | HONORING JUDGE ANTHONY J. DENNIS
# CREC-2023-05-22-pt1-PgE473-2.htm                   | PERSONAL EXPLANATION
# CREC-2023-05-22-pt1-PgH2468-7.htm                  | APPOINTMENT OF INDIVIDUAL TO HEALTH INFORMATION TECHNOLOGY ADVISORY
# CREC-2023-05-22-pt1-PgH2501-11.htm                 | H.R. 3564.
# CREC-2023-05-22-pt1-PgH2501-15.htm                 | H.R. 3568.
# CREC-2023-05-22-pt1-PgH2468-3.htm                  | AMERICANS RULED BY BUREAUCRATS
# CREC-2023-05-22-pt1-PgE471-4.htm                   | HONORING THE LIFE AND LEGACY OF MR. THOMAS DIXON
# CREC-2023-05-22-pt1-PgE471-5.htm                   | HONORING JAZMIN SANCHEZ TORREZ WITH FIRST PLACE IN THE NEW HAMPSHIRE
# CREC-2023-05-22-pt1-PgH2468-2.htm                  | RECOGNIZING HUDSON COUNTY SHERIFF FRANK SCHILLARI
# CREC-2023-05-22-pt1-PgH2501-14.htm                 | H.R. 3567.
# CREC-2023-05-22-pt1-PgE475-3.htm                   | HONORING THE EXTRAORDINARY LIFE AND LEGACY OF SELMA MAYOR GEORGE
# CREC-2023-05-22-pt1-PgH2501-16.htm                 | H.R. 3569.
# CREC-2023-05-22-pt1-PgH2497-2.htm                  | EXECUTIVE COMMUNICATIONS, ETC.
# CREC-2023-05-22-pt1-PgE473-5.htm                   | RECOGNIZING LEAH PEER
# CREC-2023-05-22-pt1-PgE473-4.htm                   | CELEBRATING UCLA MENS VOLLEYBALL TEAM FOR THEIR 2023 NATIONAL
# CREC-2023-05-22-pt1-PgE471-6.htm                   | RECOGNIZING JEWISH AMERICAN HERITAGE MONTH
# CREC-2023-05-22-pt1-PgH2501-17.htm                 | H.R. 3570.
# CREC-2023-05-22-pt1-PgE475-2.htm                   | HONORING UNT POLICE CHIEF ED REYNOLDS
# CREC-2023-05-22-pt1-PgH2482-2.htm                  | AFTER RECESS
# CREC-2023-05-22-pt1-PgE472.htm                     | RECOGNIZING THE 58TH ANNIVERSARY OF THE HEAD START PROGRAM
# CREC-2023-05-22-pt1-PgH2466-3.htm                  | PREPARING FOR TYPHOON MAWAR
# CREC-2023-05-22-pt1-PgH2484-4.htm                  | NATO SUPPORTING UKRAINE
# CREC-2023-05-22-pt1-PgH2466-2.htm                  | POLYCRISIS HURTS SENIORS
# CREC-2023-05-22-pt1-PgE473.htm                     | CELEBRATING MAX COOK AND HIS 32 YEARS OF SERVICE TO THE MISSOURI
# CREC-2023-05-22-pt1-PgD486-3.htm                   | No Title Found
# CREC-2023-05-22-pt1-PgH2501-2.htm                  | H.R. 3555.
# CREC-2023-05-22-pt1-PgH2501-19.htm                 | H.R. 3572.
# CREC-2023-05-22-pt1-PgH2486-5.htm                  | CBC HONORS AMERICA'S VETERANS
# CREC-2023-05-22-pt1-PgH2486-4.htm                  | LET'S SAVE OUR CHILDREN
# CREC-2023-05-22-pt1-PgH2501-18.htm                 | H.R. 3671.
# CREC-2023-05-22-pt1-PgH2501-3.htm                  | H.R. 3556.
# CREC-2023-05-22-pt1-PgD486-2.htm                   | No Title Found
# CREC-2023-05-22-pt1-PgE474.htm                     | RECOGNIZING THE 75TH ANNIVERSARY OF THE EMERGENCY RESCUE SQUAD
# CREC-2023-05-22-pt1-PgH2501-7.htm                  | H.R. 3560.
# CREC-2023-05-22-pt1-PgH2501-20.htm                 | H.R. 3573.
# CREC-2023-05-22-pt1-PgH2484-2.htm                  | MOMENT OF SILENCE HONORING FORMER CONGRESSMAN MARION BERRY
# CREC-2023-05-22-pt1-PgH2484-3.htm                  | REMOVAL OF NAME OF MEMBER AS COSPONSOR OF H.R. 915
# CREC-2023-05-22-pt1-PgH2501-21.htm                 | H.R. 8574.
# CREC-2023-05-22-pt1-PgH2501-6.htm                  | H.R. 3559.
# CREC-2023-05-22-pt1-PgE475.htm                     | RECOGNIZING THE 25TH ANNIVERSARY OF THE CENTER FOR DOMESTIC
# CREC-2023-05-22-pt1-PgH2501-4.htm                  | H.R. 3557.
# CREC-2023-05-22-pt1-PgH2501-23.htm                 | H.R. 3576.
# CREC-2023-05-22-pt1-PgH2486-3.htm                  | CELEBRATING THE 135TH ANNIVERSARY OF THE YWCA OF NORTHEASTERN NEW YORK
# CREC-2023-05-22-pt1-PgH2486-2.htm                  | RED FLAG LAWS
# CREC-2023-05-22-pt1-PgH2468-8.htm                  | APPOINTMENT OF MEMBER TO BOARD OF VISITORS TO THE UNITED STATES NAVAL
# CREC-2023-05-22-pt1-PgH2501-22.htm                 | H.R. 3575.
# CREC-2023-05-22-pt1-PgH2501-5.htm                  | H.R. 3558.
# CREC-2023-05-22-pt1-PgE476.htm                     | RECOGNIZING THE SERVICE OF SERGEANT MAJOR JOHN A. THOMAS, THE DIRECTOR
# CREC-2023-05-22-pt1-PgH2498-2.htm                  | PUBLIC BILLS AND RESOLUTIONS
# CREC-2023-05-22-pt1-PgH2465-2.htm                  | DESIGNATION OF SPEAKER PRO TEMPORE
# CREC-2023-05-22-pt1-PgH2502-14.htm                 | H.R. 3590.
# CREC-2023-05-22-pt1-PgH2504.htm                    | DELETIONS OF SPONSORS FROM PUBLIC BILLS AND RESOLUTIONS
# CREC-2023-05-22-pt1-PgD486.htm                     | No Title Found
# CREC-2023-05-22-pt1-PgD487.htm                     | HALT FENTANYL ACT; PROVIDING FOR CONGRESSIONAL DISAPPROVAL OF THE RULE
# CREC-2023-05-22-pt1-PgH2465.htm                    | No Title Found
# CREC-2023-05-22-pt1-PgH2471.htm                    | CHINA FINANCIAL THREAT MITIGATION ACT OF 2023
# CREC-2023-05-22-pt1-PgH2465-3.htm                  | MORNING-HOUR DEBATE
# CREC-2023-05-22-pt1-PgH2502-15.htm                 | H.R. 3591.
# CREC-2023-05-22-pt1-PgH2485-6.htm                  | IMPROVING MILITARY HOUSING
# CREC-2023-05-22-pt1-PgH2485-4.htm                  | STOPPING THE INFLUX OF FENTANYL
# CREC-2023-05-22-pt1-PgH2502-17.htm                 | H.R. 3593.
# CREC-2023-05-22-pt1-PgH2467-3.htm                  | PRAYER
# CREC-2023-05-22-pt1-PgH2467.htm                    | RECESS
# CREC-2023-05-22-pt1-PgH2498.htm                    | REPORTS OF COMMITTEES ON PUBLIC BILLS AND RESOLUTIONS
# CREC-2023-05-22-pt1-PgH2483-2.htm                  | PREVENTING THE FINANCING OF ILLEGAL SYNTHETIC DRUGS ACT
# CREC-2023-05-22-pt1-PgH2502-3.htm                  | H.R. 3579.
# CREC-2023-05-22-pt1-PgH2502-2.htm                  | H.R. 3578.
# CREC-2023-05-22-pt1-PgH2483-3.htm                  | CHINA FINANCIAL THREAT MITIGATION ACT OF 2023
# CREC-2023-05-22-pt1-PgH2472.htm                    | KOREAN AMERICAN VIETNAM ALLIES LONG OVERDUE FOR RELIEF ACT
# CREC-2023-05-22-pt1-PgH2466.htm                    | RECOGNIZING SSAB STEEL
# CREC-2023-05-22-pt1-PgH2467-2.htm                  | AFTER RECESS
# CREC-2023-05-22-pt1-PgH2502-16.htm                 | H.R. 3592.
# CREC-2023-05-22-pt1-PgH2485-5.htm                  | PASSING IMMIGRATION REFORM
# CREC-2023-05-22-pt1-PgH2465-4.htm                  | RECOGNIZING NATIONAL EMERGENCY MEDICAL SERVICES
# CREC-2023-05-22-pt1-PgH2502-12.htm                 | H.R. 3588.
# CREC-2023-05-22-pt1-PgH2502.htm                    | H.R. 3577.
# CREC-2023-05-22-pt1-PgH2467-6.htm                  | RECOGNIZING NICOLE MORADZADEH
# CREC-2023-05-22-pt1-PgH2502-6.htm                  | H.R. 3582.
# CREC-2023-05-22-pt1-PgH2502-7.htm                  | H.R. 3583.
# CREC-2023-05-22-pt1-PgH2467-7.htm                  | CELEBRATING ASIAN AMERICAN, NATIVE HAWAIIAN, AND PACIFIC ISLANDER
# CREC-2023-05-22-pt1-PgH2465-5.htm                  | PAYING TRIBUTE TO THE LONG AND DISTINGUISHED CAREER OF BRUNSWICK COUNTY
# CREC-2023-05-22-pt1-PgH2502-13.htm                 | H.R. 3589.
# CREC-2023-05-22-pt1-PgH2502-11.htm                 | H.R. 3587.
# CREC-2023-05-22-pt1-PgH2485-2.htm                  | HONORING THE LIFE OF JERRY HOGAN, SR.
# CREC-2023-05-22-pt1-PgH2501.htm                    | CONSTITUTIONAL AUTHORITY AND SINGLE SUBJECT STATEMENTS
# CREC-2023-05-22-pt1-PgH2467-5.htm                  | PLEDGE OF ALLEGIANCE
# CREC-2023-05-22-pt1-PgH2502-5.htm                  | H.R. 3581.
# CREC-2023-05-22-pt1-PgH2502-4.htm                  | H.R. 3580.
# CREC-2023-05-22-pt1-PgH2474.htm                    | VET-TEC AUTHORIZATION ACT OF 2023
# CREC-2023-05-22-pt1-PgH2467-4.htm                  | THE JOURNAL
# CREC-2023-05-22-pt1-PgH2500.htm                    | MEMORIALS
# CREC-2023-05-22-pt1-PgH2485-3.htm                  | THE CLOCK IS TICKING
# CREC-2023-05-22-pt1-PgH2502-10.htm                 | H.R. 3586.

# %%
from bs4 import BeautifulSoup
import os

def extract_titles_and_content(directory, char_limit=1000):
    extracted_data = []

    for filename in os.listdir(directory):
        if filename.endswith('.htm'):
            file_path = os.path.join(directory, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                soup = BeautifulSoup(file, 'html.parser')
                
                # Find the link to www.gpo.gov and its next sibling
                gpo_link = soup.find('a', href='https://www.gpo.gov')
                if gpo_link:
                    title_tag = gpo_link.find_next_sibling(text=True)
                    if title_tag:
                        title = title_tag.strip().upper()  # Extract and clean the title

                        # Start capturing content after the title
                        content = ""
                        content_start = title_tag.next_element
                        while len(content) < char_limit and content_start:
                            # Skip over non-text elements like tags
                            if not content_start.name:
                                content += str(content_start)
                            content_start = content_start.next_element

                        content = content[:char_limit]  # Limit the content length
                        extracted_data.append({'file': filename, 'title': title, 'content': content})
                    else:
                        extracted_data.append({'file': filename, 'title': 'No title found', 'content': ''})
                else:
                    extracted_data.append({'file': filename, 'title': 'No title found', 'content': ''})

    return extracted_data

# Example usage
directory_path = '../Episodes/CREC-2023-05-22/html'
data = extract_titles_and_content(directory_path)
for item in data:
#    print(f"File: {item['file']:<50} Title: {item['title']}")
    print(f"Content: {item['content']}\n")
# Out:
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content: 2. Much work needs to be
# done to keep crops on the table, to keep the electricity and the wires,
# keep the minerals coming to produce all the things we need to keep
# energy, all of that. The ESA needs to be revisited and actually focused
# on truly recovering species but not used as a weapon to stop things
# people need, our economies need, rural economies especially. That is
# some of the work we do in the Western Caucus.
#   Mr. Speaker, I appreciate, again, Chairman Newhouse's leadership on
# this and the opportunity to speak on it here tonight. There is much
# more that I could say; you know me.
#   Mr. NEWHOUSE. Mr. Speaker, Mr. LaMalfa is correct, there are a lot of
# things that we should talk about. We have a limited amount of time, but
# he is very good at expressing the needs of the people that he
# represents and making sure that people understand.
#   Mr. LaMALFA. Mr. Speaker, I am a farmer in my real life. I hope I
# talk plainly enough to get my thoughts across.
#   Mr. NEWHOUSE. Mr. Spe
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content: www.govinfo.gov,
#  free of charge to the user. The information is updated online each day
#  the Congressional Record is published. For more information,
#  contact the GPO Customer Contact Center, U.S. Government Publishing Office.
#  Phone 202-512-1800, or 866-512-1800 (toll-free). E-Mail,
#  contactcenter@gpo.gov.
# To place an order for any of these products, visit
#  the U.S. Government Online Bookstore at: bookstore.gpo.gov. Mail
#  orders to: Superintendent of Documents, P.O. Box 979050, St. Louis,
#  MO 63197-9000, or phone orders to 866-512-1800 (toll-free),
#  202-512-1800 (D.C. area), or fax to 202-512-2104. Remit check or
#  money order, made payable to the Superintendent of Documents, or use
#  VISA, MasterCard, Discover, American Express, or GPO Deposit Account.
# Following each session of Congress, the daily Congressional Record
#  is revised, printed, permanently bound and sold by the
#  Superintendent of Documents in individual parts or by sets.
# With the exception of copyright
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
#
#
# Content:
# /var/folders/2q/p_zv12bn2b9_54913k31ckmh0000gn/T/ipykernel_79200/3917495203.py:16: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   title_tag = gpo_link.find_next_sibling(text=True)
